# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report,accuracy_score
import numpy as np

# %%
df=pd.read_csv("insurance.csv")

# %%
df
# Out:
#     age  weight  height  income_lpa  smoker       city      occupation  \
# 0    67   119.8    1.56     2.92000   False     Jaipur         retired
# 1    36   101.1    1.83    34.28000   False    Chennai      freelancer
# 2    39    56.8    1.64    36.64000   False     Indore      freelancer
# 3    22   109.4    1.55     3.34000    True     Mumbai         student
# 4    69    62.2    1.60     3.94000    True     Indore         retired
# ..  ...     ...     ...         ...     ...        ...             ...
# 95   36    52.8    1.57    19.64000   False     Indore  business_owner
# 96   26   113.8    1.54    34.01000   False      Delhi     private_job
# 97   52    60.8    1.80    44.86000   False  Hyderabad      freelancer
# 98   27   101.1    1.82    28.30000   False    Kolkata  business_owner
# 99   40    70.0    1.59    28.16664    True  Bangalore  government_job
#
#    insurance_premium_category        bmi
# 0                        High  49.227482
# ...

# %%
df.sample(5)
# Out:
#     age  weight  height  income_lpa  smoker        city   occupation  \
# 13   28    93.4    1.84       11.95   False     Kolkata   freelancer
# 86   35    66.0    1.89       37.38   False   Hyderabad   freelancer
# 39   51   100.6    1.68       11.99    True   Bangalore   unemployed
# 35   59    59.3    1.69       43.28    True  Chandigarh  private_job
# 32   47   113.7    1.90       50.00   False   Jalandhar  private_job
#
#    insurance_premium_category        bmi
# 13                        Low  27.587429
# 86                        Low  18.476526
# 39                       High  35.643424
# 35                     Medium  20.762578
# 32                     Medium  31.495845

# %%
df["occupation"].unique()
# Out:
# array(['retired', 'freelancer', 'student', 'government_job',
#        'business_owner', 'unemployed', 'private_job'], dtype=object)

# %%
dff=df.copy()

# %%
dff["bmi"]=dff["weight"]/(dff["height"])**2

# %%
def age_grp(age):
    if age<25:
        return "young"
    elif age<45:
        return "adult"
    elif age<60:
        return "middle_age"
    else:
        return "senior"

# %%
dff["age_group"]=dff["age"].apply(age_grp)

# %%
dff
# Out:
#     age  weight  height  income_lpa  smoker       city      occupation  \
# 0    67   119.8    1.56     2.92000   False     Jaipur         retired
# 1    36   101.1    1.83    34.28000   False    Chennai      freelancer
# 2    39    56.8    1.64    36.64000   False     Indore      freelancer
# 3    22   109.4    1.55     3.34000    True     Mumbai         student
# 4    69    62.2    1.60     3.94000    True     Indore         retired
# ..  ...     ...     ...         ...     ...        ...             ...
# 95   36    52.8    1.57    19.64000   False     Indore  business_owner
# 96   26   113.8    1.54    34.01000   False      Delhi     private_job
# 97   52    60.8    1.80    44.86000   False  Hyderabad      freelancer
# 98   27   101.1    1.82    28.30000   False    Kolkata  business_owner
# 99   40    70.0    1.59    28.16664    True  Bangalore  government_job
#
#    insurance_premium_category        bmi   age_group
# 0                        High  49.227482      senior
# ...

# %%
def life_risk(row):
    if row["smoker"] and row["bmi"]>30:
        return "high"
    elif row["smoker"] or row["bmi"]>27:
        return "medium"
    else:
        return "low"

# %%
dff["lifestyle_risk"]=dff.apply(life_risk,axis=1)

# %%
dff
# Out:
#     age  weight  height  income_lpa  smoker       city      occupation  \
# 0    67   119.8    1.56     2.92000   False     Jaipur         retired
# 1    36   101.1    1.83    34.28000   False    Chennai      freelancer
# 2    39    56.8    1.64    36.64000   False     Indore      freelancer
# 3    22   109.4    1.55     3.34000    True     Mumbai         student
# 4    69    62.2    1.60     3.94000    True     Indore         retired
# ..  ...     ...     ...         ...     ...        ...             ...
# 95   36    52.8    1.57    19.64000   False     Indore  business_owner
# 96   26   113.8    1.54    34.01000   False      Delhi     private_job
# 97   52    60.8    1.80    44.86000   False  Hyderabad      freelancer
# 98   27   101.1    1.82    28.30000   False    Kolkata  business_owner
# 99   40    70.0    1.59    28.16664    True  Bangalore  government_job
#
#    insurance_premium_category        bmi   age_group lifestyle_risk
# ...

# %%
tier_1_cities = ["Mumbai", "Delhi", "Bangalore", "Chennai", "Kolkata", "Hyderabad", "Pune"]
tier_2_cities = [
    "Jaipur", "Chandigarh", "Indore", "Lucknow", "Patna", "Ranchi", "Visakhapatnam", "Coimbatore",
    "Bhopal", "Nagpur", "Vadodara", "Surat", "Rajkot", "Jodhpur", "Raipur", "Amritsar", "Varanasi",
    "Agra", "Dehradun", "Mysore", "Jabalpur", "Guwahati", "Thiruvananthapuram", "Ludhiana", "Nashik",
    "Allahabad", "Udaipur", "Aurangabad", "Hubli", "Belgaum", "Salem", "Vijayawada", "Tiruchirappalli",
    "Bhavnagar", "Gwalior", "Dhanbad", "Bareilly", "Aligarh", "Gaya", "Kozhikode", "Warangal",
    "Kolhapur", "Bilaspur", "Jalandhar", "Noida", "Guntur", "Asansol", "Siliguri"
]

# %%
def city_tier(city):
    if city in tier_1_cities:
        return 1
    elif city in tier_2_cities:
        return 2
    else:
        return 3

# %%
dff["city_tier"]=dff["city"].apply(city_tier)

# %%
dff
# Out:
#     age  weight  height  income_lpa  smoker       city      occupation  \
# 0    67   119.8    1.56     2.92000   False     Jaipur         retired
# 1    36   101.1    1.83    34.28000   False    Chennai      freelancer
# 2    39    56.8    1.64    36.64000   False     Indore      freelancer
# 3    22   109.4    1.55     3.34000    True     Mumbai         student
# 4    69    62.2    1.60     3.94000    True     Indore         retired
# ..  ...     ...     ...         ...     ...        ...             ...
# 95   36    52.8    1.57    19.64000   False     Indore  business_owner
# 96   26   113.8    1.54    34.01000   False      Delhi     private_job
# 97   52    60.8    1.80    44.86000   False  Hyderabad      freelancer
# 98   27   101.1    1.82    28.30000   False    Kolkata  business_owner
# 99   40    70.0    1.59    28.16664    True  Bangalore  government_job
#
#    insurance_premium_category        bmi   age_group lifestyle_risk  city_tier
# ...

# %%
dff.drop(columns=["age","weight","height","city","smoker"],inplace=True)

# %%
dff
# Out:
#     income_lpa      occupation insurance_premium_category        bmi  \
# 0      2.92000         retired                       High  49.227482
# 1     34.28000      freelancer                        Low  30.189017
# 2     36.64000      freelancer                        Low  21.118382
# 3      3.34000         student                     Medium  45.535900
# 4      3.94000         retired                       High  24.296875
# ..         ...             ...                        ...        ...
# 95    19.64000  business_owner                        Low  21.420747
# 96    34.01000     private_job                        Low  47.984483
# 97    44.86000      freelancer                        Low  18.765432
# 98    28.30000  business_owner                        Low  30.521676
# 99    28.16664  government_job                        Low  27.688778
#
#      age_group lifestyle_risk  city_tier
# 0       senior         medium          2
# 1        adult         medium          1
# ...

# %%
dff.columns
# Out:
# Index(['income_lpa', 'occupation', 'insurance_premium_category', 'bmi',
#        'age_group', 'lifestyle_risk', 'city_tier'],
#       dtype='object')

# %%
X=dff[['income_lpa', 'occupation', 'bmi',
       'age_group', 'lifestyle_risk', 'city_tier']]
Y=dff["insurance_premium_category"]

# %%
X
# Out:
#     income_lpa      occupation        bmi   age_group lifestyle_risk  \
# 0      2.92000         retired  49.227482      senior         medium
# 1     34.28000      freelancer  30.189017       adult         medium
# 2     36.64000      freelancer  21.118382       adult            low
# 3      3.34000         student  45.535900       young           high
# 4      3.94000         retired  24.296875      senior         medium
# ..         ...             ...        ...         ...            ...
# 95    19.64000  business_owner  21.420747       adult            low
# 96    34.01000     private_job  47.984483       adult         medium
# 97    44.86000      freelancer  18.765432  middle_age            low
# 98    28.30000  business_owner  30.521676       adult         medium
# 99    28.16664  government_job  27.688778       adult         medium
#
#     city_tier
# 0           2
# 1           1
# 2           2
# 3           1
# 4           2
# ..        ...
# 95          2
# ...

# %%
Y
# Out:
# 0       High
# 1        Low
# 2        Low
# 3     Medium
# 4       High
#        ...
# 95       Low
# 96       Low
# 97       Low
# 98       Low
# 99       Low
# Name: insurance_premium_category, Length: 100, dtype: object

# %%
cat_features=['occupation','age_group', 'lifestyle_risk', 'city_tier']
num_features=['income_lpa','bmi']

# %%
# create column transformer and OHE
preprocessing=ColumnTransformer(transformers=[
    ("cat",OneHotEncoder(),cat_features),
    ("num","passthrough",num_features)
])

# %%
# Create a pipeline with preprocessin and RandomForestClassifer
pipeline=Pipeline(steps=[
    ("preprocessing",preprocessing),
    ("classifier",RandomForestClassifier(random_state=42))
])

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)
pipeline.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('cat', OneHotEncoder(),
#                                                   ['occupation', 'age_group',
#                                                    'lifestyle_risk',
#                                                    'city_tier']),
#                                                  ('num', 'passthrough',
#                                                   ['income_lpa', 'bmi'])])),
#                 ('classifier', RandomForestClassifier(random_state=42))])

# %%
y_predict=pipeline.predict(X_test)
accuracy_score(Y_test,y_predict)
# Out:
# 0.6

# %%
X_test.sample(5)
# Out:
#     income_lpa      occupation        bmi   age_group lifestyle_risk  \
# 44       50.00     private_job  30.078125  middle_age           high
# 18       38.14  business_owner  24.969136  middle_age         medium
# 80       50.00      unemployed  34.350461  middle_age         medium
# 33        1.46         retired  21.791064      senior            low
# 30       32.97  business_owner  29.937519       adult         medium
#
#     city_tier
# 44          2
# 18          3
# 80          2
# 33          1
# 30          1

# %%
#saving weights into Pickle 
import pickle
pickle_model_path="../model.pkl"
with open(pickle_model_path,"wb") as f:
    pickle.dump(pipeline,f)
